# %% [markdown]
# # 🐻‍❄️ 투빅스 정규세션 4주차 1교시 Generative AI 코드 과제 🐻‍❄️

# %% [markdown]
# 이번 과제에서는 VAE 모델과 DCGAN 모델을 직접 구현 및 학습하여 이미지를 생성해보고, 그 결과를 비교해보겠습니다.
#
# - **VAE(Variational AutoEncoder)**: 입력 데이터를 저차원의 잠재 공간(latent space)으로 압축한 뒤, 이 공간의 확률 분포를 기반으로 다시 원본 데이터를 복원 및 생성하도록 하는 모델
#
# - **GAN(Generative Adversarial Network)**: 생성자(Generator)와 판별자(Discriminator)라는 두 개의 네트워크가 서로 경쟁하며 학습하는 모델
#   * Generator: Random noise를 입력받아 진짜(Real) 같은 가짜(Fake) 데이터를 생성 (=위조지폐범)
#   * Discriminator: 입력받은 데이터가 Real인지 Fake인지 구분 (=경찰)
#
# - **DCGAN (Deep Convolutional GAN)**: 기존 GAN은 단순한 MLP(Multi-Layer Perceptron) 구조인 반면, DCGAN은 이를 Convolutional 구조로 확장하여 이미지의 생성 성능을 향상시킨 모델

# %% [markdown]
# ### **모듈 임포트 및 디바이스 설정**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### **데이터셋 준비 (MNIST dataset)**

# %%
batch_size = 128
epochs = 30

transform = transforms.Compose([
    transforms.ToTensor()
])

dataset = torchvision.datasets.MNIST(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

# train / val split
train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = torch.utils.data.random_split(
    dataset,
    [train_size, val_size]
)

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)

val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# 100%|██████████| 9.91M/9.91M [00:02<00:00, 4.90MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 134kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.26MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 14.4MB/s]

# %% [markdown]
# ## **VAE(Variational AutoEncoder) 모델 정의 및 학습**
#
# * Encoder: 입력 데이터 x를 받아 잠재 공간(Latent Space)의 파라미터를 추출
#   * 고차원의 입력데이터를 저차원의 평균과 로그 분산으로 변환
#     * 💡 빈칸 채우기 hint) `self.fc1`을 거쳐 특징을 추출한 뒤, 두 개의 서로 다른 선형 레이어를 통해 각각 평균과 로그 분산을 계산
#
# * Latent Space & Reparameterization
#   * 잠재 변수 z를 직접 고정된 값으로 뽑는 것이 아니라, encoder가 만든 분포(평균, 로그 분산)에서 샘플링함
#   * Reparameterization Trick: backpropagation는 샘플링 연산을 통과할 수 없다는 문제를 해결하기 위해 샘플링 과정을 미분 가능한 형태로 만들기 위한 수식
#
# * Decoder
#   * 샘플링된 잠재 변수 z를 다시 원래의 입력 데이터 차원으로 복원

# %% [markdown]
# ![image_vae.png](data:image/png;base64,...)

# %% [markdown]
# 참고 코드: https://github.com/NoviceStone/VAE/blob/master/models.py

# %%
class VAE(nn.Module):

    def __init__(self, input_size=784, hidden_size=400, latent_size=20, data_type="binary"):
        super(VAE, self).__init__()

        # Encoder: layers
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc21 = nn.Linear(hidden_size, latent_size)  # 평균(mu)
        self.fc22 = nn.Linear(hidden_size, latent_size)  # 로그 분산(logvar)

        # Decoder: layers
        self.fc3 = nn.Linear(latent_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, input_size)

        self.data_type = data_type

    def encode(self, x):
        h1 = F.relu(self.fc1(x))
        mean = self.fc21(h1) # 🤔 빈칸을 채워주세요
        log_var = self.fc22(h1) # 🤔 빈칸을 채워주세요
        return mean, log_var

    @staticmethod
    def reparameterize(mean, log_var):

        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)

        z = mean + std * eps
        return z

    def decode(self, z):

        h3 = F.relu(self.fc3(z))

        logits = self.fc4(h3)
        probs = torch.sigmoid(logits)

        return probs

    def forward(self, x):

        x = x.view(-1, 784)

        mu, logvar = self.encode(x)

        z = self.reparameterize(mu, logvar)

        recon = self.decode(z)

        return recon, mu, logvar

# %% [markdown]
# ### **VAE loss (ELBO)**
# * Reconsturction Loss: 복원된 이미지(`recon_x`)가 원본 이미지(`x`)와 얼마나 다른지 측정
# * KL Divergence: 잠재공간의 분포가 표준 정규븐포와 얼마나 다른지 측정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def elbo_loss(x, recon_x, mu, logvar):

    B = x.size(0)

    x = x.view(-1, 784)

    BCE = F.binary_cross_entropy(recon_x, x, reduction='sum') / B # 🤔 빈칸을 채워주세요

    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp()) / B # 🤔 빈칸을 채워주세요

    total_loss = BCE + KLD # 🤔 빈칸을 채워주세요

    return total_loss

# %% [markdown]
# ## **🙋 [VAE] Question 1**
# VAE의 ELBO Loss에 KL Divergence 항이 포함되는 이유를 설명해주세요.
#
#
#
# *
#
# VAE의 ELBO Loss에 KL Divergence 항이 포함되는 이유는, 인코더가 학습한 잠재변수 분포
# 𝑞
# (
# 𝑧
# ∣
# 𝑥
# )
# q(z∣x)를 사전분포
# 𝑝
# (
# 𝑧
# )
# p(z) (일반적으로 표준정규분포)와 가깝게 만들기 위해서이다.
#
# KL Divergence 항이 없다면, 모델은 단순히 입력 데이터를 잘 복원하는 데만 집중하게 되어 잠재공간이 비정상적이고 불규칙한 분포를 가지게 된다. 이렇게 되면 새로운 데이터를 생성할 때 의미 있는 샘플을 만들기 어려워진다.
#
# KL Divergence는 이런 문제를 방지하고, 잠재공간을 연속적이고 구조화된 형태로 정규화하여 샘플링 및 생성 성능을 향상시키는 역할을 한다.
#
# 따라서 ELBO는 재구성 성능을 나타내는 Reconstruction Loss와, 잠재분포를 정규화하는 KL Divergence를 함께 최소화하도록 구성된다.

# %%
vae = VAE().to(device)
optimizer = optim.Adam(vae.parameters(), lr=1e-3)

for epoch in range(epochs):


    # ========== Train ==========
    vae.train()
    train_loss = 0

    for x,_ in train_loader:

        x = x.to(device)

        recon, mu, logvar = vae(x)

        loss = elbo_loss(x,recon, mu, logvar)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    train_loss /= len(train_dataset)


    # ========== Validation ==========
    vae.eval()
    val_loss = 0

    with torch.no_grad():

        for x,_ in val_loader:

            x = x.to(device)

            recon, mu, logvar = vae(x)

            loss = elbo_loss(x, recon, mu, logvar)

            val_loss += loss.item()

    val_loss /= len(val_dataset)

    print(f"[VAE] Epoch {epoch+1}/{epochs} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
# Out:
# [VAE] Epoch 1/30 | Train Loss: 1.3246 | Val Loss: 1.0282
# [VAE] Epoch 2/30 | Train Loss: 0.9638 | Val Loss: 0.9266
# [VAE] Epoch 3/30 | Train Loss: 0.9030 | Val Loss: 0.8932
# [VAE] Epoch 4/30 | Train Loss: 0.8785 | Val Loss: 0.8760
# [VAE] Epoch 5/30 | Train Loss: 0.8631 | Val Loss: 0.8630
# [VAE] Epoch 6/30 | Train Loss: 0.8534 | Val Loss: 0.8570
# [VAE] Epoch 7/30 | Train Loss: 0.8456 | Val Loss: 0.8489
# [VAE] Epoch 8/30 | Train Loss: 0.8401 | Val Loss: 0.8438
# [VAE] Epoch 9/30 | Train Loss: 0.8358 | Val Loss: 0.8406
# [VAE] Epoch 10/30 | Train Loss: 0.8321 | Val Loss: 0.8371
# [VAE] Epoch 11/30 | Train Loss: 0.8290 | Val Loss: 0.8366
# [VAE] Epoch 12/30 | Train Loss: 0.8262 | Val Loss: 0.8327
# [VAE] Epoch 13/30 | Train Loss: 0.8245 | Val Loss: 0.8299
# [VAE] Epoch 14/30 | Train Loss: 0.8220 | Val Loss: 0.8294
# [VAE] Epoch 15/30 | Train Loss: 0.8203 | Val Loss: 0.8264
# [VAE] Epoch 16/30 | Train Loss: 0.8187 | Val Loss: 0.8262
# [VAE] Epoch 17/30 | Train Loss: 0.8174 | Val Loss: 0.8256
# [VAE] Epoch 18/30 | Train Loss: 0.8156 | Val Loss: 0.8232
# [VAE] Epoch 19/30 | Train Loss: 0.8146 | Val Loss: 0.8230
# [VAE] Epoch 20/30 | Train Loss: 0.8135 | Val Loss: 0.8209
# [VAE] Epoch 21/30 | Train Loss: 0.8122 | Val Loss: 0.8213
# [VAE] Epoch 22/30 | Train Loss: 0.8113 | Val Loss: 0.8198
# [VAE] Epoch 23/30 | Train Loss: 0.8102 | Val Loss: 0.8197
# [VAE] Epoch 24/30 | Train Loss: 0.8094 | Val Loss: 0.8187
# [VAE] Epoch 25/30 | Train Loss: 0.8087 | Val Loss: 0.8179
# [VAE] Epoch 26/30 | Train Loss: 0.8080 | Val Loss: 0.8171
# [VAE] Epoch 27/30 | Train Loss: 0.8074 | Val Loss: 0.8179
# [VAE] Epoch 28/30 | Train Loss: 0.8067 | Val Loss: 0.8159
# [VAE] Epoch 29/30 | Train Loss: 0.8059 | Val Loss: 0.8148
# [VAE] Epoch 30/30 | Train Loss: 0.8050 | Val Loss: 0.8174

# %% [markdown]
# **VAE sampling 시각화**

# %%
with torch.no_grad():

    z = torch.randn(64,20).to(device)

    samples = vae.decode(z).view(-1,1,28,28)

    grid = make_grid(samples,8)

plt.imshow(grid.permute(1,2,0).cpu())
plt.title("VAE Samples")
plt.show()

# %% [markdown]
# ## **DCGAN(Deep Convolutional GAN) 모델 정의 및 학습**
# - Weight Initialization
#   - 모델의 가중치는 평균이 0, 표준편차가 0.02인 정규분포로 초기화
#   - 기존 GAN의 학습 불안정성을 줄이기 위해 DCGAN 논문에서 제안한 아이디어
#
# - Generator (생성자)
#   - Transposed Convolution: 저차원의 잠재 벡터를 고해상도 이미지로 확장
#   - Batch Normalization: 각 layer의 출력을 정규화하여 학습의 안정성을 높이고 gradient vanishing 문제를 해결
#   - Activation: 중간 layer에는 ReLU를 통해 빠른 학습을 진행하고, 마지막 layer에는 이미지의 픽셀 값 범위([-1, 1])를 맞추기 위해 Tanh를 사용
#
# - Discriminator (판별자)
#   - Strided Convolution: pooling 대신 stride를 사용하여 특징을 추출
#   - LeakyReLU: 음수 영역에 작은 양수 기울기를 부여하여 Gradient Vanishing 문제를 해결
#   - Activation: 마지막 layer에 sigmoid를 사용하여 real(1)/fake(0) 사이의 확률 값을 출력

# %% [markdown]
# ![The-architecture-of-vanilla-GANs.png](data:image/png;base64,...)

# %% [markdown]
# 참고 코드: https://github.com/Natsu6767/DCGAN-PyTorch/blob/master/dcgan.py

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)) # [-1, 1]
])

dataset = torchvision.datasets.MNIST(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

# train / val split
train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = torch.utils.data.random_split(
    dataset,
    [train_size, val_size]
)

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True
)

val_loader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False
)

# %%
# weight 초기화 함수

def weights_init(m):

    classname = m.__class__.__name__

    if classname.find("Conv") != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)

    elif classname.find("BatchNorm") != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
latent_size = 20

class Generator(nn.Module):

    def __init__(self):

        super().__init__()

        self.tconv1 = nn.ConvTranspose2d(latent_size,256,7,1,0,bias=False)
        self.bn1 = nn.BatchNorm2d(256)

        self.tconv2 = nn.ConvTranspose2d(256,128,4,2,1,bias=False)
        self.bn2 = nn.BatchNorm2d(128)

        self.tconv3 = nn.ConvTranspose2d(128,64,4,2,1,bias=False)
        self.bn3 = nn.BatchNorm2d(64)

        self.tconv4 = nn.ConvTranspose2d(64,1,3,1,1,bias=False)

    def forward(self,x):

        x = F.relu(self.bn1(self.tconv1(x)))
        x = F.relu(self.bn2(self.tconv2(x)))
        x = F.relu(self.bn3(self.tconv3(x)))

        x = torch.tanh(self.tconv4(x))

        return x

# %%
class Discriminator(nn.Module):

    def __init__(self):

        super().__init__()

        self.conv1 = nn.Conv2d(in_channels=1,out_channels=64,kernel_size=4,stride=2,padding=1,bias=False)

        self.conv2 = nn.Conv2d(64,128,4,2,1,bias=False)
        self.bn2 = nn.BatchNorm2d(128)

        self.conv3 = nn.Conv2d(128,256,4,2,1,bias=False)
        self.bn3 = nn.BatchNorm2d(256)

        self.conv4 = nn.Conv2d(256,1,3,1,0,bias=False)

    def forward(self,x):

        x = F.leaky_relu(self.conv1(x),0.2,True)

        x = F.leaky_relu(self.bn2(self.conv2(x)),0.2,True)

        x = F.leaky_relu(self.bn3(self.conv3(x)),0.2,True)

        x = torch.sigmoid(self.conv4(x))

        return x.view(-1)

# %%
G = Generator().to(device)
D = Discriminator().to(device)

G.apply(weights_init)
D.apply(weights_init)

criterion = nn.BCELoss()

optG = optim.Adam(G.parameters(),0.0002,betas=(0.5,0.999))
optD = optim.Adam(D.parameters(),0.0002,betas=(0.5,0.999))

# %%
for epoch in range(epochs):

    G.train()
    D.train()

    train_lossD = 0
    train_lossG = 0

    for x,_ in train_loader:

        x = x.to(device)

        real = torch.ones(x.size(0)).to(device)
        fake = torch.zeros(x.size(0)).to(device)


        # ========== Train Discriminator ==========

        z = torch.randn(x.size(0),latent_size,1,1).to(device)

        fake_img = G(z)

        loss_real = criterion(D(x), real)
        loss_fake = criterion(D(fake_img.detach()), fake)

        lossD = loss_real + loss_fake

        optD.zero_grad()
        lossD.backward()
        optD.step()


        # ========== Train Generator ==========

        lossG = criterion(D(fake_img), torch.ones_like(D(fake_img))) # 🤔 빈칸을 채워주세요

        optG.zero_grad()
        lossG.backward()
        optG.step()

        train_lossD += lossD.item()
        train_lossG += lossG.item()

    train_lossD /= len(train_loader)
    train_lossG /= len(train_loader)

    print(f"[DCGAN] Epoch {epoch+1}/{epochs} | Train D Loss {train_lossD:.4f} | Train G Loss {train_lossG:.4f}")
# Out:
# [DCGAN] Epoch 1/30 | Train D Loss 0.8036 | Train G Loss 1.7028
# [DCGAN] Epoch 2/30 | Train D Loss 0.9112 | Train G Loss 1.4225
# [DCGAN] Epoch 3/30 | Train D Loss 0.9724 | Train G Loss 1.3469
# [DCGAN] Epoch 4/30 | Train D Loss 1.0077 | Train G Loss 1.3114
# [DCGAN] Epoch 5/30 | Train D Loss 0.9990 | Train G Loss 1.3359
# [DCGAN] Epoch 6/30 | Train D Loss 0.9935 | Train G Loss 1.3533
# [DCGAN] Epoch 7/30 | Train D Loss 1.0023 | Train G Loss 1.3704
# [DCGAN] Epoch 8/30 | Train D Loss 0.9892 | Train G Loss 1.3848
# [DCGAN] Epoch 9/30 | Train D Loss 0.9663 | Train G Loss 1.4337
# [DCGAN] Epoch 10/30 | Train D Loss 0.9468 | Train G Loss 1.4613
# [DCGAN] Epoch 11/30 | Train D Loss 0.9177 | Train G Loss 1.5148
# [DCGAN] Epoch 12/30 | Train D Loss 0.9208 | Train G Loss 1.5217
# [DCGAN] Epoch 13/30 | Train D Loss 0.8818 | Train G Loss 1.5985
# [DCGAN] Epoch 14/30 | Train D Loss 0.8668 | Train G Loss 1.6335
# [DCGAN] Epoch 15/30 | Train D Loss 0.8557 | Train G Loss 1.6528
# [DCGAN] Epoch 16/30 | Train D Loss 0.8333 | Train G Loss 1.7107
# [DCGAN] Epoch 17/30 | Train D Loss 0.8291 | Train G Loss 1.7195
# [DCGAN] Epoch 18/30 | Train D Loss 0.8212 | Train G Loss 1.7480
# [DCGAN] Epoch 19/30 | Train D Loss 0.8055 | Train G Loss 1.7712
# [DCGAN] Epoch 20/30 | Train D Loss 0.7802 | Train G Loss 1.8102
# [DCGAN] Epoch 21/30 | Train D Loss 0.7803 | Train G Loss 1.8451
# [DCGAN] Epoch 22/30 | Train D Loss 0.7735 | Train G Loss 1.8599
# [DCGAN] Epoch 23/30 | Train D Loss 0.7625 | Train G Loss 1.8958
# [DCGAN] Epoch 24/30 | Train D Loss 0.7511 | Train G Loss 1.9119
# [DCGAN] Epoch 25/30 | Train D Loss 0.7356 | Train G Loss 1.9514
# [DCGAN] Epoch 26/30 | Train D Loss 0.7399 | Train G Loss 1.9595
# [DCGAN] Epoch 27/30 | Train D Loss 0.7424 | Train G Loss 1.9748
# [DCGAN] Epoch 28/30 | Train D Loss 0.6851 | Train G Loss 2.0475
# [DCGAN] Epoch 29/30 | Train D Loss 0.7135 | Train G Loss 2.0443
# [DCGAN] Epoch 30/30 | Train D Loss 0.6971 | Train G Loss 2.0739

# %% [markdown]
# **DCGAN Sampling 시각화**

# %%
G.eval()

with torch.no_grad():

    z = torch.randn(64,latent_size,1,1).to(device)

    samples = G(z)

grid = make_grid(samples,8,normalize=True)

plt.imshow(grid.permute(1,2,0).cpu())
plt.title("DCGAN Samples")
plt.axis("off")
plt.show()

# %% [markdown]
# ## **🙋 [GAN] Question 2-1**
# VAE와 DCGAN으로 MNIST 이미지를 생성한 결과 VAE는 흐릿한 이미지, DCGAN은 선명한 이미지가 생성된 것을 알 수 있습니다. 그 이유를 VAE와 GAN의 특징과 학습 방식을 포함하여 설명해주세요.
#
# *
#
# VAE는 ELBO를 최대화하는 방식으로 학습되며 Reconstruction Loss와 KL Divergence를 함께 최소화한다. 이 과정에서 입력 데이터를 평균적으로 잘 복원하도록 학습되기 때문에 여러 출력의 평균적인 결과를 생성하게 되어 이미지가 흐릿해지는 경향이 있다. 또한 잠재공간을 정규분포에 가깝게 만들도록 하기에 표현력이 제한될 수 있다.
#
# 반면 GAN은 Generator와 Discriminator가 서로 경쟁하는 adversarial learning을 통해 학습된다. Generator는 Discriminator를 속이기 위해 실제 데이터와 구별되지 않는 이미지를 생성하도록 학습되며, 이 과정에서 고주파 디테일과 선명한 특징을 학습하게 된다.
#
# 따라서 VAE는 확률적이고 안정적인 대신 흐릿한 이미지를 생성하고, GAN은 데이터 분포를 더 날카롭게 모방하여 선명한 이미지를 생성한다.

# %% [markdown]
# ## **🙋 [GAN] Question 2-2**
# GAN 학습 과정에서 Generator의 Loss가 증가하는 것이 반드시 모델 성능 악화를 의미하지 않는 이유는 무엇인지 설명해주세요.
#
# *
#
# GAN 학습에서 Generator의 Loss는 Discriminator의 성능에 크게 의존하므로, Loss 값이 증가하는 것이 반드시 모델 성능 악화를 의미하지는 않는다.
#
# Generator의 Loss는 Discriminator가 생성된 이미지를 얼마나 잘 구별하는지에 따라 결정되는데, Discriminator가 더 강해질수록 Generator의 Loss는 증가할 수 있다. 이는 Generator의 성능이 나빠졌기 때문이 아니라 상대적으로 Discriminator가 더 잘 학습되었기 때문이다.
#
# 또한 GAN은 두 모델이 동시에 학습되는 min-max 게임 구조이기 때문에 Loss 값이 단조롭게 감소하지 않고 진동하는 특성을 가진다. 따라서 Generator Loss의 증가는 학습 과정에서 자연스러운 현상이며, 모델의 실제 성능은 생성된 이미지의 품질로 평가하는 것이 더 적절하다.

# %% [markdown]
# 수고하셨습니다 ☺️
